# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

#adding in numpy for np.nan removals**.
import numpy as np

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date      Lat       Lng  \
# 0        0         Coquimbo      CL  2022-02-05 06:09:06 -29.9533  -71.3436
# 1        1            Pevek      RU  2022-02-05 06:00:38  69.7008  170.3133
# 2        2  Arraial Do Cabo      BR  2022-02-05 06:03:27 -22.9661  -42.0278
# 3        3          Mataura      NZ  2022-02-05 06:05:13 -46.1927  168.8643
# 4        4        Carnarvon      AU  2022-02-05 06:03:39 -24.8667  113.6333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     66.15        80           0        3.78           clear sky
# 1    -26.95        99          83        5.97       broken clouds
# 2     75.60        89          98       21.83     overcast clouds
# 3     59.49        49          15        6.85          few clouds
# 4     95.67        42          51        9.80       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(40)
# Out:
#      City_ID              City Country                 Date      Lat  \
# 2          2   Arraial Do Cabo      BR  2022-02-05 06:03:27 -22.9661
# 8          8            Avarua      CK  2022-02-05 06:07:52 -21.2078
# 15        15            Yulara      AU  2022-02-05 06:05:37 -25.2406
# 22        22             Alofi      NU  2022-02-05 06:09:22 -19.0595
# 32        32           Samarai      PG  2022-02-05 06:09:46 -10.6167
# 33        33         Hithadhoo      MV  2022-02-05 06:03:33  -0.6000
# 35        35         Boa Vista      BR  2022-02-05 06:09:47   2.8197
# 41        41        Butaritari      KI  2022-02-05 06:06:17   3.0707
# 45        45        Popondetta      PG  2022-02-05 06:09:53  -8.7537
# 51        51            Atuona      PF  2022-02-05 06:03:30  -9.8000
# 57        57             Lubao      PH  2022-02-05 06:11:01  14.9167
# 65        65           Rikitea      PF  2022-02-05 06:03:26 -23.1203
# 73        73            Faanui      PF  2022-02-05 06:11:50 -16.4833
# ...

# %%
# 4a. Determine if there are any empty rows.
#testing null values**.
preferred_cities_df.count()
preferred_cities_df.isnull().sum()

#NULL VALUE DETECTED ON COUNTRY VALUES**.
# Out:
# City_ID                0
# City                   0
# Country                1
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df=preferred_cities_df.dropna()
clean_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
#testing null drops are correct***.
clean_df.count()

#Data appears sound***.
# Out:
# City_ID                143
# City                   143
# Country                143
# Date                   143
# Lat                    143
# Lng                    143
# Max Temp               143
# Humidity               143
# Cloudiness             143
# Wind Speed             143
# Current Description    143
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 2   Arraial Do Cabo      BR     75.60     overcast clouds -22.9661  -42.0278
# 8            Avarua      CK     78.85          few clouds -21.2078 -159.7750
# 15           Yulara      AU     86.22           clear sky -25.2406  130.9889
# 22            Alofi      NU     79.81          light rain -19.0595 -169.9187
# 32          Samarai      PG     84.85     overcast clouds -10.6167  150.6667
# 33        Hithadhoo      MV     82.47     overcast clouds  -0.6000   73.0833
# 35        Boa Vista      BR     80.58           clear sky   2.8197  -60.6733
# 41       Butaritari      KI     82.98       broken clouds   3.0707  172.7902
# 45       Popondetta      PG     86.34     overcast clouds  -8.7537  148.2534
# 51           Atuona      PF     78.58          few clouds  -9.8000 -139.0333
#
#    Hotel Name
# 2
# 8
# 15
# 22
# 32
# 33
# 35
# 41
# 45
# 51

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    print(params)
    #Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
        print("Hotel not found....skipping")
# Out:
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-22.9661,-42.0278'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-21.2078,-159.775'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-25.2406,130.9889'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-19.0595,-169.9187'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-10.6167,150.6667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '-0.6,73.0833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '2.8197,-60.6733'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBjhTd-KAsxNQvwfGESf-KF9UgeX0syidw', 'location': '3.0707,172.7902'}
# ...

# %%
#7 - checking data frame***.
hotel_df.head(40)

#NOTE: the data shows numerous null values that are being recorded as blank string values for hotel names***.
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 2     Arraial Do Cabo      BR     75.60     overcast clouds -22.9661
# 8              Avarua      CK     78.85          few clouds -21.2078
# 15             Yulara      AU     86.22           clear sky -25.2406
# 22              Alofi      NU     79.81          light rain -19.0595
# 32            Samarai      PG     84.85     overcast clouds -10.6167
# 33          Hithadhoo      MV     82.47     overcast clouds  -0.6000
# 35          Boa Vista      BR     80.58           clear sky   2.8197
# 41         Butaritari      KI     82.98       broken clouds   3.0707
# 45         Popondetta      PG     86.34     overcast clouds  -8.7537
# 51             Atuona      PF     78.58          few clouds  -9.8000
# 57              Lubao      PH     85.14       broken clouds  14.9167
# 65            Rikitea      PF     78.58           clear sky -23.1203
# 73             Faanui      PF     80.60          light rain -16.4833
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
#fixing for nulls*.
#solutions taken from: 
#https://www.kite.com/python/answers/how-to-replace-each-empty-string-in-a-pandas-dataframe-with-nan-in-python
hotel_df = hotel_df.replace(r'^\s*$', np.NaN, regex=True)

# %%
#7a - checking that nulls are fixed***.
hotel_df.head(40)

#data shows that null string values are now replaced with Nan values on Hotel Name**.
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 2     Arraial Do Cabo      BR     75.60     overcast clouds -22.9661
# 8              Avarua      CK     78.85          few clouds -21.2078
# 15             Yulara      AU     86.22           clear sky -25.2406
# 22              Alofi      NU     79.81          light rain -19.0595
# 32            Samarai      PG     84.85     overcast clouds -10.6167
# 33          Hithadhoo      MV     82.47     overcast clouds  -0.6000
# 35          Boa Vista      BR     80.58           clear sky   2.8197
# 41         Butaritari      KI     82.98       broken clouds   3.0707
# 45         Popondetta      PG     86.34     overcast clouds  -8.7537
# 51             Atuona      PF     78.58          few clouds  -9.8000
# 57              Lubao      PH     85.14       broken clouds  14.9167
# 65            Rikitea      PF     78.58           clear sky -23.1203
# 73             Faanui      PF     80.60          light rain -16.4833
# ...

# %%
#7b - droping value; no null values detected*.
clean_hotel_df=hotel_df.dropna()
clean_hotel_df.head(40)
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 2     Arraial Do Cabo      BR     75.60     overcast clouds -22.9661
# 8              Avarua      CK     78.85          few clouds -21.2078
# 15             Yulara      AU     86.22           clear sky -25.2406
# 22              Alofi      NU     79.81          light rain -19.0595
# 32            Samarai      PG     84.85     overcast clouds -10.6167
# 33          Hithadhoo      MV     82.47     overcast clouds  -0.6000
# 35          Boa Vista      BR     80.58           clear sky   2.8197
# 41         Butaritari      KI     82.98       broken clouds   3.0707
# 45         Popondetta      PG     86.34     overcast clouds  -8.7537
# 51             Atuona      PF     78.58          few clouds  -9.8000
# 57              Lubao      PH     85.14       broken clouds  14.9167
# 65            Rikitea      PF     78.58           clear sky -23.1203
# 73             Faanui      PF     80.60          light rain -16.4833
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation1.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
#NOTE: instructions does not indicate retention of 'hotel name' ; however, it was retained anyway***.

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = clean_hotel_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
